# %%
import matplotlib.pyplot as plt
import numpy as np
x=["a","b","c","d"]
y=[80,70,75,64]
z=[20,30,40,60]
width=0.2
p=np.arange(len(x))
p1=[j+width for j in p]
plt.xlabel("language",fontsize=10)
plt.ylabel("No",fontsize=15)
plt.title("plot1",fontsize=15)
plt.bar(x,y)
plt.legend()
plt.show()
# Out:
# C:\Users\harshit\AppData\Local\Temp\ipykernel_21000\3309996466.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
